# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Set up

# %%
# !sudo apt-get update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,463 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [76.0 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,517 kB]
# Hit:14 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [738 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:18 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [872 kB]
# Hit:20 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,823 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,954 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [771 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,242 kB]
# Get:25 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [934 kB]
# Get:26 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Fetched 14.7 MB in 3s (4,303 kB/s)
# Reading package lists... Done

# %%
# Install jdk8
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
import os
# Set environment variable JAVA_HOME.
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
# Out:
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode
# openjdk version "1.8.0_312"
# OpenJDK Runtime Environment (build 1.8.0_312-8u312-b07-0ubuntu1~18.04-b07)
# OpenJDK 64-Bit Server VM (build 25.312-b07, mixed mode)

# %%
# !pip install bigdl==0.13.0
# Out:
# Collecting bigdl==0.13.0
#   Downloading BigDL-0.13.0-py2.py3-none-manylinux1_x86_64.whl (114.0 MB)
#      |████████████████████████████████| 114.0 MB 52 kB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from bigdl==0.13.0) (1.19.5)
# Collecting pyspark==2.4.6
#   Downloading pyspark-2.4.6.tar.gz (218.4 MB)
#      |████████████████████████████████| 218.4 MB 55 kB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from bigdl==0.13.0) (1.15.0)
# Collecting py4j==0.10.7
#   Downloading py4j-0.10.7-py2.py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 46.4 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.6-py2.py3-none-any.whl size=218814407 sha256=86002d458a00c828d296ffd97a8e1425357aa70792a40f49cd4cf29a419f1d0f
#   Stored in directory: /root/.cache/pip/wheels/f1/42/b0/ba397759613f4feb1611021a2503e60e344e546671b2ae04f8
# Successfully built pyspark
# Installing collected packages: py4j, pyspark, bigdl
# Successfully installed bigdl-0.13.0 py4j-0.10.7 pyspark-2.4.6

# %%
#!pip install pillow==4.0.0

# %% [markdown]
# # Data Processing

# %%
# %cd /content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/
# !unzip "/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/VinaFood21_7Class.zip"

# %%
# path = "/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/"
# import glob
# import pandas as pd

# nameclass = ['Banhcan', 'Banhhoi', 'Banhuot', 'Bokho', 'Hacao', 'Phalau', 'Tauhu']
# imgData = []
# imgLabel = []
# label=0
# for name in nameclass:
  
#   for img in glob.glob(path + name + '/*.*'):
#     print(name)
#     imgData.append(img.replace(path+name+'/',''))
#     imgLabel.append(label)

#   label = label + 1

# %%
# data = pd.DataFrame(imgData, columns=None)
# data['label'] = imgLabel
# data.sample(10)

# %%
# data.to_csv(path+'label.txt', header=False, index=False)

# %%
# # Move all image into 1 folder
# import shutil
# import os
    
# target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/VinaFood7'

# nameclass = ['Banhcan', 'Banhhoi', 'Banhuot', 'Bokho', 'Hacao', 'Phalau', 'Tauhu']    
# for name in nameclass:
#   source_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/' + name
#   file_names = os.listdir(source_dir)
#   for file_name in file_names:
#       shutil.move(os.path.join(source_dir, file_name), target_dir)

# %% [markdown]
# Spliting Train/ Test/ Validation

# %%
# import pandas as pd
# data = pd.read_csv('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/label.txt', header=None)
# print(len(data))
# data.head()

# %%
# from sklearn.model_selection import train_test_split
# train, t = train_test_split(data, test_size=0.2, random_state=42)
# print(len(train))
# train.head()

# %%
# test, val = train_test_split(t, test_size=0.1, random_state=42)
# print(len(train))
# print(len(test))
# print(len(val))

# %%
# train.to_csv('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/train.txt', header=None)
# test.to_csv('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/test.txt', header=None)
# val.to_csv('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/val.txt', header=None)

# %% [markdown]
# Moving images for each set (train/ test/ val)

# %%
# # Read train test val txt
# import pandas as pd
# train = pd.read_csv('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/train/train.txt', names=['name','label'])
# test = pd.read_csv('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/test/test.txt', names=['name','label'])
# val = pd.read_csv('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/val/val.txt', names=['name','label'])
# print(len(train))
# print(len(test))
# print(len(val))
# train.head()

# %%
# import shutil
# import os
# #Move images corresponding to train
# source_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/VinaFood7'
# file_names = os.listdir(source_dir)    
# target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/train'

# for file_name in train['name']:
#     shutil.move(os.path.join(source_dir, file_name), target_dir)

# #Move images corresponding to test
# source_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/VinaFood7'
# file_names = os.listdir(source_dir)    
# target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/test'

# for file_name in test['name']:
#     shutil.move(os.path.join(source_dir, file_name), target_dir)

# #Move images corresponding to val
# source_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/VinaFood7'
# file_names = os.listdir(source_dir)    
# target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/val'

# for file_name in val['name']:
#     shutil.move(os.path.join(source_dir, file_name), target_dir)

# %%
# # Count again
# import os, os.path
# target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/train'
# print('Train:',len([name for name in os.listdir(target_dir)]))
# target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/test'
# print('Test:',len([name for name in os.listdir(target_dir)]))
# target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/val'
# print('Val:',len([name for name in os.listdir(target_dir)]))
# target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/VinaFood7'
# print('VinaFood7:',len([name for name in os.listdir(target_dir)]))

# %% [markdown]
# # Prepare data RDD for BigDL

# %%
import matplotlib
matplotlib.use('Agg')
# %pylab inline

import pandas
import datetime as dt

from bigdl.nn.layer import *
from bigdl.nn.criterion import *
from bigdl.optim.optimizer import *
from bigdl.util.common import *
from bigdl.dataset.transformer import *
from pyspark import SparkContext
from matplotlib.pyplot import imshow
from bigdl.util import common
import matplotlib.pyplot as plt
sc=SparkContext.getOrCreate(conf=create_spark_conf().setMaster("local[*]").set("spark.driver.memory","6g"))

init_engine()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Prepending /usr/local/lib/python3.7/dist-packages/bigdl/share/conf/spark-bigdl.conf to sys.path

# %%
# # Count again
nameclass = ['Banhhoi', 'Banhuot', 'Bokho', 'Phalau']
cnt=0
for name in nameclass:
  import os, os.path
  target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/'+ name
  count = len([name for name in os.listdir(target_dir)])
  cnt = cnt + count
  print(count)

print('Total: ',cnt)
# Out:
# 1241
# 1159
# 701
# 726
# Total:  3827

# %% [markdown]
# ## Read and resize images

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import zipfile  # unziping 
import glob  # finding image paths
from skimage.io import imread  # reading images
from skimage.transform import resize  # resizing images
#from torchvision import transforms
#from PIL import Image
import os

IMG_SIZE = 28 #(image resolution of 256 x 256 used for example)
num_chanel = 3

nameclass = ['Banhhoi', 'Banhuot', 'Bokho', 'Phalau']
#.img_classLength = [1265, 1168, 706, 735]

lst_dct = {}
imgs_dct = {}
labels_dct = {}

label_num = 0

# for name in nameclass:

#   target_dir = '/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/'+ name +'/*.jpg'
#   imgs_list = sorted(glob.glob(target_dir))
#   lst_dct[name] = imgs_list
#   imgs_dct[name] = np.empty((len(lst_dct[name]), IMG_SIZE, IMG_SIZE, num_chanel))

#   imgs_label = []
#   #cnt100 = 0
#   for i, img_path in enumerate(lst_dct[name]):
#     # if cnt100 >= 10000:
#     #   continue
#     # else:
#     # read image
#     img = imread(img_path)
#     print(img_path)
#     #cnt100 = cnt100 + 1

#     #Refine exceptable images
#     if len(img.shape) == 3 and img.shape[2] == 3:
#       # resize image (1 channel used for example; 1 for gray-scale, 3 for RGB-scale)
#       img = resize(img, output_shape=(IMG_SIZE, IMG_SIZE, num_chanel), preserve_range=True)
#       # save to numpy array
#       imgs_dct[name][i] = img
#       imgs_label.append(label_num)
#       #continue
      
#     else:
#       print(img.shape)
#       #os.remove(img_path)

    
  
#   labels_dct[name] = imgs_label
#   label_num = label_num + 1

# %%
# imgs_dct['Phalau'].shape

# %%
# # # Count again
# nameclass = ['Banhhoi', 'Banhuot', 'Bokho', 'Phalau']
# cnt=0
# for name in nameclass:
#   print(name)
#   print('lst: ', len(lst_dct[name]))
#   print('imgs: ', len(imgs_dct[name]))
#   print('label: ', len(labels_dct[name]))

# print('Total: ',cnt)

# %%
# imgs_dct['Banhhoi'].shape

# %%
# imgs_dct['Banhuot'].shape

# %%
# imgs_dct['Bokho'].shape

# %%
# nameclass_mn = ['Banhuot', 'Bokho', 'Phalau']

# image_data = imgs_dct['Banhhoi']
# Y_data = np.array(labels_dct['Banhhoi'])

# for name in nameclass_mn:
#   image_data = np.concatenate((image_data, imgs_dct[name]))
#   Y_data = np.concatenate((Y_data, np.array(labels_dct[name])))

# %%
# print(image_data.shape)
# print(Y_data.shape)

# %% [markdown]
# ### Save images and labels data

# %%
# # Save
# with open('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/Food4_imagesData.npy', 'wb') as f:
#     np.save(f, image_data)

# with open('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/Food4_lablesData.npy', 'wb') as f:
#     np.save(f, Y_data)

# %% [markdown]
# ### Quickly load images and labels data as Numpy

# %%
# import matplotlib
# matplotlib.use('Agg')
# %pylab inline

# import pandas
# import datetime as dt
# from sklearn.model_selection import train_test_split

# from bigdl.nn.layer import *
# from bigdl.nn.criterion import *
# from bigdl.optim.optimizer import *
# from bigdl.util.common import *
# from bigdl.dataset.transformer import *
# from pyspark import SparkContext
# from matplotlib.pyplot import imshow
# from bigdl.util import common
# import matplotlib.pyplot as plt
# sc=SparkContext.getOrCreate(conf=create_spark_conf().setMaster("local[4]").set("spark.driver.memory","8g"))

# init_engine()

# %%
#Load
with open('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/Food4_imagesData.npy', 'rb') as f:
    image_data = np.load(f)

with open('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/Food4_lablesData.npy', 'rb') as f:
    Y_data = np.load(f)

# %%
X_train, X_val_test, Y_train, Y_val_test = train_test_split(image_data, Y_data, test_size = 0.3, random_state= 42)
X_val, X_test, Y_val, Y_test = train_test_split(X_val_test, Y_val_test, test_size = 0.5, random_state = 42)

# %%
# Open header

training_mean = np.mean(X_train)
training_std = np.std(X_train)
rdd_train_images = sc.parallelize(X_train)
rdd_train_labels = sc.parallelize(Y_train)
rdd_val_images = sc.parallelize(X_val)
rdd_val_labels = sc.parallelize(Y_val)
rdd_test_images = sc.parallelize(X_test)
rdd_test_labels = sc.parallelize(Y_test)

train_data = rdd_train_images.zip(rdd_train_labels).map(lambda x:
                                    common.Sample.from_ndarray(
                                    (x[0] - training_mean) / training_std,
                                    x[1] + 1))

val_data = rdd_val_images.zip(rdd_val_labels).map(lambda x:
                                    common.Sample.from_ndarray(
                                    (x[0] - training_mean) / training_std,
                                    x[1] + 1))

test_data = rdd_test_images.zip(rdd_test_labels).map(lambda x:
                                    common.Sample.from_ndarray(
                                    (x[0] - training_mean) / training_std,
                                    x[1] + 1))

# %%
train_data = train_data.map(lambda s: Sample.from_ndarray(np.resize(s.features[0].to_ndarray(), (IMG_SIZE, IMG_SIZE, 3)), s.label.to_ndarray()))
val_data = val_data.map(lambda s: Sample.from_ndarray(np.resize(s.features[0].to_ndarray(), (IMG_SIZE, IMG_SIZE, 3)), s.label.to_ndarray()))
test_data = test_data.map(lambda s: Sample.from_ndarray(np.resize(s.features[0].to_ndarray(), (IMG_SIZE, IMG_SIZE, 3)), s.label.to_ndarray()))
#print(train_data.count())
#print(test_data.count())
#print(val_data.count())

# %% [markdown]
# # Main

# %%
# import matplotlib
# matplotlib.use('Agg')
# %pylab inline

# import pandas
# import datetime as dt

# from bigdl.nn.layer import *
# from bigdl.nn.criterion import *
# from bigdl.optim.optimizer import *
# from bigdl.util.common import *
# from bigdl.dataset.transformer import *
# from pyspark import SparkContext
# from matplotlib.pyplot import imshow
# from bigdl.util import common
# import matplotlib.pyplot as plt
# sc=SparkContext.getOrCreate(conf=create_spark_conf().setMaster("local[*]").set("spark.driver.memory","8g"))

# init_engine()

# %%
learning_rate = 0.005
num_epochs = 5
#batch_size = 4

num_classes = 4
batchSize=128
#IMG_SIZE = (224, 224)

# %%
# Create a LeNet model
def build_model(class_num):
    model = Sequential()
    model.add(Reshape([3, IMG_SIZE, IMG_SIZE]))
    model.add(SpatialConvolution(3, 6, 5, 5).set_name('conv1'))
    model.add(Tanh())
    model.add(SpatialMaxPooling(2, 2, 2, 2).set_name('pool1'))
    model.add(Tanh())
    model.add(SpatialConvolution(6, 12, 5, 5).set_name('conv2'))
    model.add(SpatialMaxPooling(2, 2, 2, 2).set_name('pool2'))
    model.add(Reshape([12 * 4 * 4]))
    model.add(Linear(12 * 4 * 4, 100).set_name('fc1'))
    model.add(Tanh())
    model.add(Linear(100, class_num).set_name('score'))
    model.add(LogSoftMax())
    return model
vgg16_model = build_model(num_classes)
# Out:
# creating: createSequential
# creating: createReshape
# creating: createSpatialConvolution
# creating: createTanh
# creating: createSpatialMaxPooling
# creating: createTanh
# creating: createSpatialConvolution
# creating: createSpatialMaxPooling
# creating: createReshape
# creating: createLinear
# creating: createTanh
# creating: createLinear
# creating: createLogSoftMax

# %%
# Create an Optimizer
optimizer = Optimizer(
  model=vgg16_model,
  training_rdd=train_data,
  criterion=ClassNLLCriterion(),
  optim_method=SGD(learningrate=learning_rate, learningrate_decay=0.0002),
  end_trigger=MaxEpoch(num_epochs),
  batch_size=batchSize)

# Set the validation logic
optimizer.set_validation(
    batch_size=batchSize,
    val_rdd=test_data,
    trigger=EveryEpoch(),
    val_method=[Top1Accuracy()]
)

app_name='vgg16-'+dt.datetime.now().strftime("%Y%m%d-%H%M%S")
train_summary = TrainSummary(log_dir='/tmp/bigdl_summaries',
                                     app_name=app_name)
train_summary.set_summary_trigger("Parameters", SeveralIteration(5))
val_summary = ValidationSummary(log_dir='/tmp/bigdl_summaries',
                                        app_name=app_name)
optimizer.set_train_summary(train_summary)
optimizer.set_val_summary(val_summary)
print("saving logs to ",app_name)
# Out:
# creating: createClassNLLCriterion
# creating: createDefault
# creating: createSGD
# creating: createMaxEpoch
# creating: createDistriOptimizer
# creating: createEveryEpoch
# creating: createTop1Accuracy
# creating: createTrainSummary
# creating: createSeveralIteration
# creating: createValidationSummary
# saving logs to  vgg16-20220130-013011
# /usr/local/lib/python3.7/dist-packages/bigdl/optim/optimizer.py:864: UserWarning: You are recommended to use `create` method to create an optimizer.
#   warnings.warn("You are recommended to use `create` method to create an optimizer.")

# %%
#%%time
# Boot training process
trained_model = optimizer.optimize()
print("Optimization Done.")
# Out:
# Optimization Done.

# %%
# trained_model.save('/content/drive/MyDrive/Study/ComputingParallel/VinaFood21_7Class/LenetModel')

# %%
loss = np.array(train_summary.read_scalar("Loss"))
top1 = np.array(val_summary.read_scalar("Top1Accuracy"))

plt.figure(figsize = (12,12))
plt.subplot(2,1,1)
plt.plot(loss[:,0],loss[:,1],label='loss')
plt.xlim(0,loss.shape[0]+10)
plt.grid(True)
plt.title("loss")
plt.subplot(2,1,2)
plt.plot(top1[:,0],top1[:,1],label='top1')
plt.xlim(0,loss.shape[0]+10)
plt.title("top1 accuracy")
plt.grid(True)

# %% [markdown]
# ## Evaluate Performance

# %%
def map_predict_label(l):
    return np.array(l).argmax()
def map_groundtruth_label(l):
    return int(l[0] - 1)

# %% [markdown]
# ##Train Set

# %%
#%%time
predictions = trained_model.predict(train_data)
imshow(np.column_stack([np.array(s.features[0].to_ndarray()).reshape(28,28,3) for s in train_data.take(8)]),cmap='gray'); plt.axis('off')
print('Ground Truth labels:')
print(', '.join(str(map_groundtruth_label(s.label.to_ndarray())) for s in train_data.take(8)))
print('Predicted labels:')
print(', '.join(str(map_predict_label(s)) for s in predictions.take(8)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Ground Truth labels:
# 1, 3, 0, 0, 0, 3, 2, 2
# Predicted labels:
# 1, 1, 0, 1, 1, 1, 1, 1

# %%
y_pred  = [map_groundtruth_label(s.label.to_ndarray()) for s in train_data.collect()]
y_true  = [map_predict_label(s) for s in predictions.collect()]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sn
acc = accuracy_score(y_true, y_pred)
print("The prediction accuracy is %.2f%%"%(acc*100))

cm = confusion_matrix(y_true, y_pred)
cm.shape
df_cm = pd.DataFrame(cm)
plt.figure(figsize = (10,8))
sn.heatmap(df_cm, annot=True,fmt='d');
# Out:
# The prediction accuracy is 30.47%

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
#y_pred = alex.predict(np.array(X_train, np.float32))
#y_pred = np.argmax(y_pred, axis = -1)
print("accuracy: " + str(accuracy_score(y_true, y_pred)))
#print("f1-score: " + str(f1_score(y_true, y_pred, average='macro')))
target_names = nameclass
print('Classification report in Training set')
print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
# Out:
# accuracy: 0.30470500373412995
# Classification report in Training set
#               precision    recall  f1-score   support
#
#      Banhhoi     0.0478    0.1717    0.0748       233
#      Banhuot     0.9462    0.3172    0.4751      2440
#        Bokho     0.0039    0.6667    0.0078         3
#       Phalau     0.0000    0.0000    0.0000         2
#
#     accuracy                         0.3047      2678
#    macro avg     0.2495    0.2889    0.1394      2678
# weighted avg     0.8663    0.3047    0.4394      2678

# %% [markdown]
# ## Test Set

# %%
#%%time
predictions = trained_model.predict(test_data)
imshow(np.column_stack([np.array(s.features[0].to_ndarray()).reshape(28,28,3) for s in test_data.take(8)]),cmap='gray'); plt.axis('off')
print('Ground Truth labels:')
print(', '.join(str(map_groundtruth_label(s.label.to_ndarray())) for s in test_data.take(8)))
print('Predicted labels:')
print(', '.join(str(map_predict_label(s)) for s in predictions.take(8)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Ground Truth labels:
# 0, 1, 3, 2, 0, 3, 1, 0
# Predicted labels:
# 0, 0, 1, 1, 1, 1, 1, 1

# %%
y_pred  = [map_groundtruth_label(s.label.to_ndarray()) for s in test_data.collect()]
y_true  = [map_predict_label(s) for s in predictions.collect()]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sn
acc = accuracy_score(y_true, y_pred)
print("The prediction accuracy is %.2f%%"%(acc*100))

cm = confusion_matrix(y_true, y_pred)
cm.shape
df_cm = pd.DataFrame(cm)
plt.figure(figsize = (10,8))
sn.heatmap(df_cm, annot=True,fmt='d');
# Out:
# The prediction accuracy is 29.22%

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
#y_pred = alex.predict(np.array(X_train, np.float32))
#y_pred = np.argmax(y_pred, axis = -1)
print("accuracy: " + str(accuracy_score(y_true, y_pred)))
#print("f1-score: " + str(f1_score(y_true, y_pred, average='macro')))
target_names = nameclass
print('Classification report in Training set')
print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
# Out:
# accuracy: 0.2921739130434783
# Classification report in Training set
#               precision    recall  f1-score   support
#
#      Banhhoi     0.0800    0.3137    0.1275        51
#      Banhuot     0.9325    0.2906    0.4431       523
#        Bokho     0.0000    0.0000    0.0000         0
#       Phalau     0.0000    0.0000    0.0000         1
#
#     accuracy                         0.2922       575
#    macro avg     0.2531    0.1511    0.1427       575
# weighted avg     0.8553    0.2922    0.4144       575
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
#y_pred = alex.predict(np.array(X_train, np.float32))
#y_pred = np.argmax(y_pred, axis = -1)
print("accuracy: " + str(accuracy_score(y_true, y_pred)))
#print("f1-score: " + str(f1_score(y_true, y_pred, average='macro')))
target_names = nameclass
print('Classification report in Training set')
print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
# Out:
# accuracy: 0.2921739130434783
# Classification report in Training set
#               precision    recall  f1-score   support
#
#      Banhhoi     0.0800    0.3137    0.1275        51
#      Banhuot     0.9325    0.2906    0.4431       523
#        Bokho     0.0000    0.0000    0.0000         0
#       Phalau     0.0000    0.0000    0.0000         1
#
#     accuracy                         0.2922       575
#    macro avg     0.2531    0.1511    0.1427       575
# weighted avg     0.8553    0.2922    0.4144       575
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Validation Set

# %%
#%%time
predictions = trained_model.predict(val_data)
imshow(np.column_stack([np.array(s.features[0].to_ndarray()).reshape(28,28,3) for s in val_data.take(8)]),cmap='gray'); plt.axis('off')
print('Ground Truth labels:')
print(', '.join(str(map_groundtruth_label(s.label.to_ndarray())) for s in val_data.take(8)))
print('Predicted labels:')
print(', '.join(str(map_predict_label(s)) for s in predictions.take(8)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Ground Truth labels:
# 0, 3, 1, 0, 1, 1, 1, 1
# Predicted labels:
# 1, 1, 1, 1, 1, 1, 1, 1

# %%
y_pred  = [map_groundtruth_label(s.label.to_ndarray()) for s in val_data.collect()]
y_true  = [map_predict_label(s) for s in predictions.collect()]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sn
acc = accuracy_score(y_true, y_pred)
print("The prediction accuracy is %.2f%%"%(acc*100))

cm = confusion_matrix(y_true, y_pred)
cm.shape
df_cm = pd.DataFrame(cm)
plt.figure(figsize = (10,8))
sn.heatmap(df_cm, annot=True,fmt='d');
# Out:
# The prediction accuracy is 32.58%

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
#y_pred = alex.predict(np.array(X_train, np.float32))
#y_pred = np.argmax(y_pred, axis = -1)
print("accuracy: " + str(accuracy_score(y_true, y_pred)))
#print("f1-score: " + str(f1_score(y_true, y_pred, average='macro')))
target_names = nameclass
print('Classification report in Training set')
print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
# Out:
# accuracy: 0.32578397212543553
# Classification report in Training set
#               precision    recall  f1-score   support
#
#      Banhhoi     0.0637    0.2955    0.1048        44
#      Banhuot     0.9775    0.3283    0.4915       530
#        Bokho     0.0000    0.0000    0.0000         0
#       Phalau     0.0000    0.0000    0.0000         0
#
#     accuracy                         0.3258       574
#    macro avg     0.2603    0.1559    0.1491       574
# weighted avg     0.9075    0.3258    0.4619       574
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
